# %% [markdown]
# ## Overview
#
# This notebook will show you how to create and query a table or DataFrame that you uploaded to DBFS. [DBFS](https://docs.databricks.com/user-guide/dbfs-databricks-file-system.html) is a Databricks File System that allows you to store data for querying inside of Databricks. This notebook assumes that you have a file already inside of DBFS that you would like to read from.
#
# This notebook is written in **Python** so the default cell type is Python. However, you can use different languages by using the `%LANGUAGE` syntax. Python, Scala, SQL, and R are all supported.

# %%
# File location and type
file_location = "/FileStore/tables/tips.csv"
file_type = "csv"

df = spark.read.csv(file_location,header=True,inferSchema=True)
df.show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+----------+----+------+------+---+------+----+
# total_bill| tip|   sex|smoker|day|  time|size|
# +----------+----+------+------+---+------+----+
#      16.99|1.01|Female|    No|Sun|Dinner|   2|
#      10.34|1.66|  Male|    No|Sun|Dinner|   3|
#      21.01| 3.5|  Male|    No|Sun|Dinner|   3|
#      23.68|3.31|  Male|    No|Sun|Dinner|   2|
#      24.59|3.61|Female|    No|Sun|Dinner|   4|
#      25.29|4.71|  Male|    No|Sun|Dinner|   4|
#       8.77| 2.0|  Male|    No|Sun|Dinner|   2|
#      26.88|3.12|  Male|    No|Sun|Dinner|   4|
#      15.04|1.96|  Male|    No|Sun|Dinner|   2|
#      14.78|3.23|  Male|    No|Sun|Dinner|   2|
# ...

# %%
df.printSchema()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">root
# -- total_bill: double (nullable = true)
# -- tip: double (nullable = true)
# -- sex: string (nullable = true)
# -- smoker: string (nullable = true)
# -- day: string (nullable = true)
# -- time: string (nullable = true)
# -- size: integer (nullable = true)
#
# </div>

# %%
df.columns
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[3]: [&#39;total_bill&#39;, &#39;tip&#39;, &#39;sex&#39;, &#39;smoker&#39;, &#39;day&#39;, &#39;time&#39;, &#39;size&#39;]</div>

# %% [markdown]
# Handling Categorical Features

# %%
from pyspark.ml.feature import StringIndexer
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
indexer=StringIndexer(inputCol="sex",outputCol="sex_indexed")
df_r=indexer.fit(df).transform(df)
df_r.show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+----------+----+------+------+---+------+----+-----------+
# total_bill| tip|   sex|smoker|day|  time|size|sex_indexed|
# +----------+----+------+------+---+------+----+-----------+
#      16.99|1.01|Female|    No|Sun|Dinner|   2|        1.0|
#      10.34|1.66|  Male|    No|Sun|Dinner|   3|        0.0|
#      21.01| 3.5|  Male|    No|Sun|Dinner|   3|        0.0|
#      23.68|3.31|  Male|    No|Sun|Dinner|   2|        0.0|
#      24.59|3.61|Female|    No|Sun|Dinner|   4|        1.0|
#      25.29|4.71|  Male|    No|Sun|Dinner|   4|        0.0|
#       8.77| 2.0|  Male|    No|Sun|Dinner|   2|        0.0|
# ...

# %%
indexer=StringIndexer(inputCols=["smoker","day","time"],outputCols=["smoker_indexed","day_indexed",
                                                                  "time_index"])
df_r=indexer.fit(df_r).transform(df_r)
df_r.show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+----------+----+------+------+---+------+----+-----------+--------------+-----------+----------+
# total_bill| tip|   sex|smoker|day|  time|size|sex_indexed|smoker_indexed|day_indexed|time_index|
# +----------+----+------+------+---+------+----+-----------+--------------+-----------+----------+
#      16.99|1.01|Female|    No|Sun|Dinner|   2|        1.0|           0.0|        1.0|       0.0|
#      10.34|1.66|  Male|    No|Sun|Dinner|   3|        0.0|           0.0|        1.0|       0.0|
#      21.01| 3.5|  Male|    No|Sun|Dinner|   3|        0.0|           0.0|        1.0|       0.0|
# ...

# %%
from pyspark.ml.feature import VectorAssembler
featureassembler=VectorAssembler(inputCols=['tip','size','sex_indexed','smoker_indexed','day_indexed',
                          'time_index'],outputCol="Independent Features")
output=featureassembler.transform(df_r)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
output.show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+----------+----+------+------+---+------+----+-----------+--------------+-----------+----------+--------------------+
# total_bill| tip|   sex|smoker|day|  time|size|sex_indexed|smoker_indexed|day_indexed|time_index|Independent Features|
# +----------+----+------+------+---+------+----+-----------+--------------+-----------+----------+--------------------+
#      16.99|1.01|Female|    No|Sun|Dinner|   2|        1.0|           0.0|        1.0|       0.0|[1.01,2.0,1.0,0.0...|
#      10.34|1.66|  Male|    No|Sun|Dinner|   3|        0.0|           0.0|        1.0|       0.0|[1.66,3.0,0.0,0.0...|
# ...

# %%
output.select('Independent Features').show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+--------------------+
# Independent Features|
# +--------------------+
# [1.01,2.0,1.0,0.0...|
# [1.66,3.0,0.0,0.0...|
# [3.5,3.0,0.0,0.0,...|
# [3.31,2.0,0.0,0.0...|
# [3.61,4.0,1.0,0.0...|
# [4.71,4.0,0.0,0.0...|
# [2.0,2.0,0.0,0.0,...|
# [3.12,4.0,0.0,0.0...|
# [1.96,2.0,0.0,0.0...|
# [3.23,2.0,0.0,0.0...|
# [1.71,2.0,0.0,0.0...|
# [5.0,4.0,1.0,0.0,...|
# [1.57,2.0,0.0,0.0...|
# [3.0,4.0,0.0,0.0,...|
# [3.02,2.0,1.0,0.0...|
# [3.92,2.0,0.0,0.0...|
# [1.67,3.0,1.0,0.0...|
# [3.71,3.0,0.0,0.0...|
# [3.5,3.0,1.0,0.0,...|
# (6,[0,1],[3.35,3.0])|
# +--------------------+
# only showing top 20 rows
#
# </div>

# %%
finalized_data=output.select("Independent Features","total_bill")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
finalized_data.show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+--------------------+----------+
# Independent Features|total_bill|
# +--------------------+----------+
# [1.01,2.0,1.0,0.0...|     16.99|
# [1.66,3.0,0.0,0.0...|     10.34|
# [3.5,3.0,0.0,0.0,...|     21.01|
# [3.31,2.0,0.0,0.0...|     23.68|
# [3.61,4.0,1.0,0.0...|     24.59|
# [4.71,4.0,0.0,0.0...|     25.29|
# [2.0,2.0,0.0,0.0,...|      8.77|
# [3.12,4.0,0.0,0.0...|     26.88|
# [1.96,2.0,0.0,0.0...|     15.04|
# [3.23,2.0,0.0,0.0...|     14.78|
# [1.71,2.0,0.0,0.0...|     10.27|
# [5.0,4.0,1.0,0.0,...|     35.26|
# [1.57,2.0,0.0,0.0...|     15.42|
# [3.0,4.0,0.0,0.0,...|     18.43|
# [3.02,2.0,1.0,0.0...|     14.83|
# ...

# %%
from pyspark.ml.regression import LinearRegression
##train test split
train_data,test_data=finalized_data.randomSplit([0.75,0.25])
regressor=LinearRegression(featuresCol='Independent Features', labelCol='total_bill',maxIter=20, regParam=0.3, elasticNetParam=0.7)
regressor=regressor.fit(train_data)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
regressor.coefficients
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[29]: DenseVector([3.202, 3.3388, -0.7353, 2.7197, 0.0, -0.5515])</div>

# %%
regressor.intercept
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[30]: 0.9844456808838581</div>

# %%
### Predictions
pred_results=regressor.evaluate(test_data)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
## Final comparison
pred_results.predictions.show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+--------------------+----------+------------------+
# Independent Features|total_bill|        prediction|
# +--------------------+----------+------------------+
# (6,[0,1],[1.47,2.0])|     10.77| 12.36910602717846|
#  (6,[0,1],[3.6,3.0])|     24.06| 22.52828458439594|
# (6,[0,1],[4.08,2.0])|     17.92|20.726435261890412|
#  (6,[0,1],[4.3,2.0])|      21.7|21.430884469414025|
# (6,[0,1],[5.92,3.0])|     29.03| 29.95702168191768|
# (6,[0,1],[6.73,4.0])|     48.27|35.889504993993484|
# [1.0,2.0,0.0,1.0,...|      12.6|13.583851905121682|
# [1.01,2.0,1.0,0.0...|     16.99|10.160873368004335|
# ...

# %%
### PErformance Metrics
pred_results.r2,pred_results.meanAbsoluteError,(pred_results.meanSquaredError)**0.5
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[33]: (0.4737015729404671, 4.4691736137667135, 5.852301219970224)</div>
